# %% [markdown]
# 运行环境：tf-1.12.0

# %% [markdown]
# ## TENSORFLOW - TENSORBOARD可视化

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import tensorflow as tf

# %% [markdown]
# ### tensorboard数据保存路径以及模型保存路径

# %%
tensorboard_dir = 'logs/mnist/'   # 保存目录
if tf.gfile.Exists(tensorboard_dir):
    tf.gfile.DeleteRecursively(tensorboard_dir)
tf.gfile.MakeDirs(tensorboard_dir)

# %% [markdown]
# ### 载入数据

# %%
import os
from tensorflow.examples.tutorials.mnist import input_data
# 加载mnist数据
mnist_path = '/home/liujian/tensorflow_in_action/input/MNIST_data'
data = input_data.read_data_sets(mnist_path, one_hot=True)
# embeding降维可视化用的标签以及每个点的缩略图
LABELS = os.path.join(os.getcwd(), "resources/labels_1024.tsv")  # 点标签,鼠标放在低维空间的嵌入点上就会显示出标签
SPRITES = os.path.join(os.getcwd(), "resources/sprite_1024.png")  # 点缩略图,低维空间的嵌入点用缩略图表示一目了然
# Out:
# WARNING:tensorflow:From <ipython-input-3-e462a2efe6d1>:5: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/liujian/anaconda2/envs/Ner/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/liujian/anaconda2/envs/Ner/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /home/liujian/tensorflow_in_action/input/MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /home/liujian/anaconda2/envs/Ner/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /home/liujian/tensorflow_in_action/input/MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/liujian/anaconda2/envs/Ner/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting /home/liujian/tensorflow_in_action/input/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting /home/liujian/tensorflow_in_action/input/MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/liujian/anaconda2/envs/Ner/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %% [markdown]
# ### 网络层

# %%
# 简单卷积层，为方便本章教程叙述，固定部分参数
def conv_layer(input,
               channels_in,    # 输入通道数
               channels_out,   # 输出通道数
              name='conv'):   # 名称 
    with tf.name_scope('name'):
        weights = tf.Variable(tf.truncated_normal([5, 5, channels_in, channels_out], stddev=0.05), name='W')
        biases = tf.Variable(tf.constant(0.05, shape=[channels_out]), name='B')
        conv = tf.nn.conv2d(input, filter=weights, strides=[1, 1, 1, 1], padding='SAME')
        act = tf.nn.relu(conv + biases)

        tf.summary.histogram('weights', weights)
        tf.summary.histogram('biases', biases)
        tf.summary.histogram('activations', act)
        return tf.nn.max_pool(act, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 简化全连接层
def fc_layer(input, num_inputs, num_outputs, name='fc'):
    with tf.name_scope(name):
        weights = tf.Variable(tf.truncated_normal([num_inputs, num_outputs], stddev=0.05), name='W')
        biases = tf.Variable(tf.constant(0.05, shape=[num_outputs]), name='B')
        act = tf.matmul(input, weights) + biases
        
        tf.summary.histogram('weights', weights)
        tf.summary.histogram('biases', biases)
        tf.summary.histogram('activations', act)
        
        return act

# %% [markdown]
# ### 构建网络,计算交叉熵损失与准确率

# %%
def mnist_model(learning_rate, use_two_fc, use_two_conv, hparam):
    tf.reset_default_graph()    # 重置计算图
    sess = tf.Session()

    x = tf.placeholder(tf.float32, shape=[None, 784], name="x")
    x_image = tf.reshape(x, [-1, 28, 28, 1])
    tf.summary.image('input', x_image, 3)
    y = tf.placeholder(tf.float32, shape=[None, 10], name="labels")

    if use_two_conv:    # 是否使用两个卷积
        conv1 = conv_layer(x_image, 1, 32, "conv1")
        conv_out = conv_layer(conv1, 32, 64, "conv2")
    else:
        conv1 = conv_layer(x_image, 1, 64, "conv")    # 如果使用一个卷积，则再添加一个max_pooling保证维度相通
        conv_out = tf.nn.max_pool(conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding="SAME")

    flatten_shape = conv_out.get_shape()[1:4].num_elements()
    flattened = tf.reshape(conv_out, [-1, flatten_shape])

    if use_two_fc:    # 是否使用两个全连接
        fc1 = fc_layer(flattened, flatten_shape, 1024, "fc1")
        relu = tf.nn.relu(fc1)
        embedding_input = relu
        tf.summary.histogram("fc1/relu", relu)
        embedding_size = 1024
        logits = fc_layer(fc1, 1024, 10, "fc2")
    else:
        embedding_input = flattened   # 新添加的embedding_input和embedding_size
        embedding_size = flatten_shape
        logits = fc_layer(flattened, flatten_shape, 10, "fc")

    with tf.name_scope("xent"):
        xent = tf.reduce_mean(
            tf.nn.softmax_cross_entropy_with_logits(
                logits=logits, labels=y), name="xent")
        tf.summary.scalar("xent", xent)

    with tf.name_scope("train"):
        train_step = tf.train.AdamOptimizer(learning_rate).minimize(xent)

    with tf.name_scope("accuracy"):
        correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
        tf.summary.scalar("accuracy", accuracy)

    summ = tf.summary.merge_all()    # 收集所有的summary

    # 添加embedding变量
    embedding = tf.Variable(tf.zeros([1024, embedding_size]), name="test_embedding")
    assignment = embedding.assign(embedding_input)
    saver = tf.train.Saver(max_to_keep=1)     # 保存训练过程,保存验证集上准确率最大的1个模型

    sess.run(tf.global_variables_initializer())
    writer = tf.summary.FileWriter(tensorboard_dir + hparam)
    writer.add_graph(sess.graph)
    # writer = tf.summary.FileWriter(tensorboard_dir + hparam, sess.graph)

    # embedding的配置，详见官方文档
    config = tf.contrib.tensorboard.plugins.projector.ProjectorConfig()
    embedding_config = config.embeddings.add()
    embedding_config.tensor_name = embedding.name
    embedding_config.sprite.image_path = SPRITES
    embedding_config.metadata_path = LABELS
    # Specify the width and height of a single thumbnail.
    embedding_config.sprite.single_image_dim.extend([28, 28])
    tf.contrib.tensorboard.plugins.projector.visualize_embeddings(writer, config)

    max_test_accuracy = 0.
    for i in range(2001):
        batch = data.train.next_batch(100)
        if i % 10 == 0: # 每10轮写入一次
             # 同样，最好使用验证集
            s = sess.run(summ, feed_dict={x: batch[0], y: batch[1]})
            writer.add_summary(s, i)
        if i % 500 == 0:    # 每500轮保存训练模型
            # 获取验证集的embedding
            test_accuracy, _ = sess.run([accuracy, assignment], feed_dict={x: data.test.images[:1024], y: data.test.labels[:1024]})
            if test_accuracy > max_test_accuracy:
                max_test_accuracy = test_accuracy
                saver.save(sess, os.path.join(tensorboard_dir + hparam, "model.ckpt"), i)   # 保存模型,以让projector能加载embedding向量
            print("迭代轮次: {0:>6}, 验证准确率: {1:>6.4%}".format(i, test_accuracy))

        if i % 200 == 0: # 训练, run train_op
            # 获取训练过程的原数据用于tensorboard的graph查看
            run_options = tf.RunOptions(trace_level=tf.RunOptions.FULL_TRACE)
            run_metadata = tf.RunMetadata()
            train_accuracy, _ = sess.run([accuracy, train_step], feed_dict={x: batch[0], y: batch[1]}, options=run_options, run_metadata=run_metadata)
            writer.add_run_metadata(run_metadata, 'step%03d' % i)
            print('Adding run metadata for', i)
            print("迭代轮次: {0:>6}, 训练准确率: {1:>6.4%}".format(i, train_accuracy))
        else:
            sess.run(train_step, feed_dict={x: batch[0], y: batch[1]})
            
    writer.close()

# %% [markdown]
# ### 生成超参数的字符串

# %%
def make_hparam_string(learning_rate, use_two_fc, use_two_conv):
    conv_param = "conv=2" if use_two_conv else "conv=1"
    fc_param = "fc=2" if use_two_fc else "fc=1"
    return "lr_%.0E,%s,%s" % (learning_rate, conv_param, fc_param)

# %% [markdown]
# ### 训练

# %%
for learning_rate in [1E-3, 1E-4, 1E-5]:
    for use_two_fc in [False, True]:
        for use_two_conv in [False, True]:
            hparam = make_hparam_string(learning_rate, use_two_fc, use_two_conv)
            print('Starting run for %s' % hparam)

            mnist_model(learning_rate, use_two_fc, use_two_conv, hparam)

print('Done training!')
# Out:
# Starting run for lr_1E-03,conv=1,fc=1
# WARNING:tensorflow:From <ipython-input-6-e920e537d27a>:35: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# 迭代轮次:      0, 验证准确率: 6.3477%
# Adding run metadata for 0
# 迭代轮次:      0, 训练准确率: 7.0000%
# Adding run metadata for 200
# 迭代轮次:    200, 训练准确率: 95.0000%
# Adding run metadata for 400
# 迭代轮次:    400, 训练准确率: 97.0000%
# 迭代轮次:    500, 验证准确率: 96.9727%
# Adding run metadata for 600
# 迭代轮次:    600, 训练准确率: 97.0000%
# Adding run metadata for 800
# 迭代轮次:    800, 训练准确率: 98.0000%
# 迭代轮次:   1000, 验证准确率: 97.8516%
# Adding run metadata for 1000
# 迭代轮次:   1000, 训练准确率: 97.0000%
# Adding run metadata for 1200
# 迭代轮次:   1200, 训练准确率: 96.0000%
# Adding run metadata for 1400
# 迭代轮次:   1400, 训练准确率: 100.0000%
# 迭代轮次:   1500, 验证准确率: 98.1445%
# Adding run metadata for 1600
# 迭代轮次:   1600, 训练准确率: 99.0000%
# Adding run metadata for 1800
# 迭代轮次:   1800, 训练准确率: 98.0000%
# 迭代轮次:   2000, 验证准确率: 97.5586%
# Adding run metadata for 2000
# 迭代轮次:   2000, 训练准确率: 98.0000%
# Starting run for lr_1E-03,conv=2,fc=1
# 迭代轮次:      0, 验证准确率: 8.6914%
# Adding run metadata for 0
# 迭代轮次:      0, 训练准确率: 10.0000%
# Adding run metadata for 200
# 迭代轮次:    200, 训练准确率: 96.0000%
# Adding run metadata for 400
# 迭代轮次:    400, 训练准确率: 97.0000%
# 迭代轮次:    500, 验证准确率: 97.4609%
# Adding run metadata for 600
# 迭代轮次:    600, 训练准确率: 97.0000%
# Adding run metadata for 800
# 迭代轮次:    800, 训练准确率: 98.0000%
# 迭代轮次:   1000, 验证准确率: 98.4375%
# Adding run metadata for 1000
# 迭代轮次:   1000, 训练准确率: 97.0000%
# Adding run metadata for 1200
# 迭代轮次:   1200, 训练准确率: 98.0000%
# Adding run metadata for 1400
# 迭代轮次:   1400, 训练准确率: 97.0000%
# 迭代轮次:   1500, 验证准确率: 98.4375%
# Adding run metadata for 1600
# 迭代轮次:   1600, 训练准确率: 100.0000%
# Adding run metadata for 1800
# 迭代轮次:   1800, 训练准确率: 99.0000%
# 迭代轮次:   2000, 验证准确率: 99.2188%
# Adding run metadata for 2000
# 迭代轮次:   2000, 训练准确率: 97.0000%
# Starting run for lr_1E-03,conv=1,fc=2
# 迭代轮次:      0, 验证准确率: 17.6758%
# Adding run metadata for 0
# 迭代轮次:      0, 训练准确率: 15.0000%
# Adding run metadata for 200
# 迭代轮次:    200, 训练准确率: 99.0000%
# Adding run metadata for 400
# 迭代轮次:    400, 训练准确率: 98.0000%
# 迭代轮次:    500, 验证准确率: 97.8516%
# Adding run metadata for 600
# 迭代轮次:    600, 训练准确率: 97.0000%
# Adding run metadata for 800
# 迭代轮次:    800, 训练准确率: 97.0000%
# 迭代轮次:   1000, 验证准确率: 98.3398%
# Adding run metadata for 1000
# 迭代轮次:   1000, 训练准确率: 98.0000%
# Adding run metadata for 1200
# 迭代轮次:   1200, 训练准确率: 99.0000%
# Adding run metadata for 1400
# 迭代轮次:   1400, 训练准确率: 98.0000%
# 迭代轮次:   1500, 验证准确率: 97.1680%
# Adding run metadata for 1600
# 迭代轮次:   1600, 训练准确率: 98.0000%
# Adding run metadata for 1800
# 迭代轮次:   1800, 训练准确率: 100.0000%
# 迭代轮次:   2000, 验证准确率: 98.4375%
# Adding run metadata for 2000
# 迭代轮次:   2000, 训练准确率: 98.0000%
# Starting run for lr_1E-03,conv=2,fc=2
# 迭代轮次:      0, 验证准确率: 11.4258%
# Adding run metadata for 0
# 迭代轮次:      0, 训练准确率: 11.0000%
# Adding run metadata for 200
# 迭代轮次:    200, 训练准确率: 95.0000%
# Adding run metadata for 400
# 迭代轮次:    400, 训练准确率: 97.0000%
# 迭代轮次:    500, 验证准确率: 97.7539%
# Adding run metadata for 600
# 迭代轮次:    600, 训练准确率: 97.0000%
# Adding run metadata for 800
# 迭代轮次:    800, 训练准确率: 98.0000%
# 迭代轮次:   1000, 验证准确率: 98.1445%
# Adding run metadata for 1000
# 迭代轮次:   1000, 训练准确率: 99.0000%
# Adding run metadata for 1200
# 迭代轮次:   1200, 训练准确率: 99.0000%
# Adding run metadata for 1400
# 迭代轮次:   1400, 训练准确率: 97.0000%
# 迭代轮次:   1500, 验证准确率: 98.3398%
# Adding run metadata for 1600
# 迭代轮次:   1600, 训练准确率: 98.0000%
# Adding run metadata for 1800
# 迭代轮次:   1800, 训练准确率: 98.0000%
# 迭代轮次:   2000, 验证准确率: 98.4375%
# Adding run metadata for 2000
# 迭代轮次:   2000, 训练准确率: 98.0000%
# Starting run for lr_1E-04,conv=1,fc=1
# 迭代轮次:      0, 验证准确率: 10.7422%
# Adding run metadata for 0
# 迭代轮次:      0, 训练准确率: 8.0000%
# Adding run metadata for 200
# 迭代轮次:    200, 训练准确率: 70.0000%
# Adding run metadata for 400
# 迭代轮次:    400, 训练准确率: 74.0000%
# 迭代轮次:    500, 验证准确率: 85.4492%
# Adding run metadata for 600
# 迭代轮次:    600, 训练准确率: 94.0000%
# Adding run metadata for 800
# 迭代轮次:    800, 训练准确率: 93.0000%
# 迭代轮次:   1000, 验证准确率: 90.4297%
# Adding run metadata for 1000
# 迭代轮次:   1000, 训练准确率: 93.0000%
# Adding run metadata for 1200
# 迭代轮次:   1200, 训练准确率: 92.0000%
# Adding run metadata for 1400
# 迭代轮次:   1400, 训练准确率: 94.0000%
# 迭代轮次:   1500, 验证准确率: 91.9922%
# Adding run metadata for 1600
# 迭代轮次:   1600, 训练准确率: 94.0000%
# Adding run metadata for 1800
# 迭代轮次:   1800, 训练准确率: 96.0000%
# 迭代轮次:   2000, 验证准确率: 93.8477%
# Adding run metadata for 2000
# 迭代轮次:   2000, 训练准确率: 92.0000%
# Starting run for lr_1E-04,conv=2,fc=1
# 迭代轮次:      0, 验证准确率: 11.0352%
# Adding run metadata for 0
# 迭代轮次:      0, 训练准确率: 11.0000%
# Adding run metadata for 200
# 迭代轮次:    200, 训练准确率: 90.0000%
# Adding run metadata for 400
# 迭代轮次:    400, 训练准确率: 94.0000%
# 迭代轮次:    500, 验证准确率: 91.1133%
# Adding run metadata for 600
# 迭代轮次:    600, 训练准确率: 92.0000%
# Adding run metadata for 800
# 迭代轮次:    800, 训练准确率: 94.0000%
# 迭代轮次:   1000, 验证准确率: 94.3359%
# Adding run metadata for 1000
# 迭代轮次:   1000, 训练准确率: 97.0000%
# Adding run metadata for 1200
# 迭代轮次:   1200, 训练准确率: 96.0000%
# Adding run metadata for 1400
# 迭代轮次:   1400, 训练准确率: 97.0000%
# 迭代轮次:   1500, 验证准确率: 96.0938%
# Adding run metadata for 1600
# 迭代轮次:   1600, 训练准确率: 100.0000%
# Adding run metadata for 1800
# 迭代轮次:   1800, 训练准确率: 97.0000%
# 迭代轮次:   2000, 验证准确率: 97.1680%
# Adding run metadata for 2000
# 迭代轮次:   2000, 训练准确率: 99.0000%
# Starting run for lr_1E-04,conv=1,fc=2
# 迭代轮次:      0, 验证准确率: 7.8125%
# Adding run metadata for 0
# 迭代轮次:      0, 训练准确率: 7.0000%
# Adding run metadata for 200
# 迭代轮次:    200, 训练准确率: 92.0000%
# Adding run metadata for 400
# 迭代轮次:    400, 训练准确率: 93.0000%
# 迭代轮次:    500, 验证准确率: 93.2617%
# Adding run metadata for 600
# 迭代轮次:    600, 训练准确率: 95.0000%
# Adding run metadata for 800
# 迭代轮次:    800, 训练准确率: 96.0000%
# 迭代轮次:   1000, 验证准确率: 97.0703%
# Adding run metadata for 1000
# 迭代轮次:   1000, 训练准确率: 97.0000%
# Adding run metadata for 1200
# 迭代轮次:   1200, 训练准确率: 98.0000%
# Adding run metadata for 1400
# 迭代轮次:   1400, 训练准确率: 96.0000%
# 迭代轮次:   1500, 验证准确率: 97.2656%
# Adding run metadata for 1600
# 迭代轮次:   1600, 训练准确率: 99.0000%
# Adding run metadata for 1800
# 迭代轮次:   1800, 训练准确率: 95.0000%
# 迭代轮次:   2000, 验证准确率: 97.8516%
# Adding run metadata for 2000
# 迭代轮次:   2000, 训练准确率: 97.0000%
# Starting run for lr_1E-04,conv=2,fc=2
# 迭代轮次:      0, 验证准确率: 9.4727%
# Adding run metadata for 0
# 迭代轮次:      0, 训练准确率: 16.0000%
# Adding run metadata for 200
# 迭代轮次:    200, 训练准确率: 94.0000%
# Adding run metadata for 400
# 迭代轮次:    400, 训练准确率: 96.0000%
# 迭代轮次:    500, 验证准确率: 95.7031%
# Adding run metadata for 600
# 迭代轮次:    600, 训练准确率: 98.0000%
# Adding run metadata for 800
# 迭代轮次:    800, 训练准确率: 96.0000%
# 迭代轮次:   1000, 验证准确率: 97.1680%
# Adding run metadata for 1000
# 迭代轮次:   1000, 训练准确率: 95.0000%
# Adding run metadata for 1200
# 迭代轮次:   1200, 训练准确率: 96.0000%
# Adding run metadata for 1400
# 迭代轮次:   1400, 训练准确率: 99.0000%
# 迭代轮次:   1500, 验证准确率: 97.4609%
# Adding run metadata for 1600
# 迭代轮次:   1600, 训练准确率: 98.0000%
# Adding run metadata for 1800
# 迭代轮次:   1800, 训练准确率: 99.0000%
# 迭代轮次:   2000, 验证准确率: 98.5352%
# Adding run metadata for 2000
# 迭代轮次:   2000, 训练准确率: 99.0000%
# Starting run for lr_1E-05,conv=1,fc=1
# 迭代轮次:      0, 验证准确率: 8.2031%
# Adding run metadata for 0
# 迭代轮次:      0, 训练准确率: 11.0000%
# Adding run metadata for 200
# 迭代轮次:    200, 训练准确率: 19.0000%
# Adding run metadata for 400
# 迭代轮次:    400, 训练准确率: 33.0000%
# 迭代轮次:    500, 验证准确率: 41.1133%
# Adding run metadata for 600
# 迭代轮次:    600, 训练准确率: 48.0000%
# Adding run metadata for 800
# 迭代轮次:    800, 训练准确率: 58.0000%
# 迭代轮次:   1000, 验证准确率: 64.2578%
# Adding run metadata for 1000
# 迭代轮次:   1000, 训练准确率: 72.0000%
# Adding run metadata for 1200
# 迭代轮次:   1200, 训练准确率: 69.0000%
# Adding run metadata for 1400
# 迭代轮次:   1400, 训练准确率: 79.0000%
# 迭代轮次:   1500, 验证准确率: 71.8750%
# Adding run metadata for 1600
# 迭代轮次:   1600, 训练准确率: 76.0000%
# Adding run metadata for 1800
# 迭代轮次:   1800, 训练准确率: 81.0000%
# 迭代轮次:   2000, 验证准确率: 75.1953%
# Adding run metadata for 2000
# 迭代轮次:   2000, 训练准确率: 76.0000%
# Starting run for lr_1E-05,conv=2,fc=1
# 迭代轮次:      0, 验证准确率: 14.6484%
# Adding run metadata for 0
# 迭代轮次:      0, 训练准确率: 16.0000%
# Adding run metadata for 200
# 迭代轮次:    200, 训练准确率: 35.0000%
# Adding run metadata for 400
# 迭代轮次:    400, 训练准确率: 58.0000%
# 迭代轮次:    500, 验证准确率: 65.3320%
# Adding run metadata for 600
# 迭代轮次:    600, 训练准确率: 69.0000%
# Adding run metadata for 800
# 迭代轮次:    800, 训练准确率: 62.0000%
# 迭代轮次:   1000, 验证准确率: 77.7344%
# Adding run metadata for 1000
# 迭代轮次:   1000, 训练准确率: 78.0000%
# Adding run metadata for 1200
# 迭代轮次:   1200, 训练准确率: 81.0000%
# Adding run metadata for 1400
# 迭代轮次:   1400, 训练准确率: 74.0000%
# 迭代轮次:   1500, 验证准确率: 82.1289%
# Adding run metadata for 1600
# 迭代轮次:   1600, 训练准确率: 85.0000%
# Adding run metadata for 1800
# 迭代轮次:   1800, 训练准确率: 83.0000%
# 迭代轮次:   2000, 验证准确率: 84.5703%
# Adding run metadata for 2000
# 迭代轮次:   2000, 训练准确率: 90.0000%
# Starting run for lr_1E-05,conv=1,fc=2
# 迭代轮次:      0, 验证准确率: 8.6914%
# Adding run metadata for 0
# 迭代轮次:      0, 训练准确率: 10.0000%
# Adding run metadata for 200
# 迭代轮次:    200, 训练准确率: 64.0000%
# Adding run metadata for 400
# 迭代轮次:    400, 训练准确率: 83.0000%
# 迭代轮次:    500, 验证准确率: 80.2734%
# Adding run metadata for 600
# 迭代轮次:    600, 训练准确率: 82.0000%
# Adding run metadata for 800
# 迭代轮次:    800, 训练准确率: 84.0000%
# 迭代轮次:   1000, 验证准确率: 86.5234%
# Adding run metadata for 1000
# 迭代轮次:   1000, 训练准确率: 82.0000%
# Adding run metadata for 1200
# 迭代轮次:   1200, 训练准确率: 88.0000%
# Adding run metadata for 1400
# 迭代轮次:   1400, 训练准确率: 90.0000%
# 迭代轮次:   1500, 验证准确率: 88.4766%
# Adding run metadata for 1600
# 迭代轮次:   1600, 训练准确率: 86.0000%
# Adding run metadata for 1800
# 迭代轮次:   1800, 训练准确率: 93.0000%
# 迭代轮次:   2000, 验证准确率: 90.0391%
# Adding run metadata for 2000
# 迭代轮次:   2000, 训练准确率: 93.0000%
# Starting run for lr_1E-05,conv=2,fc=2
# 迭代轮次:      0, 验证准确率: 12.6953%
# Adding run metadata for 0
# 迭代轮次:      0, 训练准确率: 10.0000%
# Adding run metadata for 200
# 迭代轮次:    200, 训练准确率: 76.0000%
# Adding run metadata for 400
# 迭代轮次:    400, 训练准确率: 85.0000%
# 迭代轮次:    500, 验证准确率: 84.3750%
# Adding run metadata for 600
# 迭代轮次:    600, 训练准确率: 88.0000%
# Adding run metadata for 800
# 迭代轮次:    800, 训练准确率: 87.0000%
# 迭代轮次:   1000, 验证准确率: 89.2578%
# Adding run metadata for 1000
# 迭代轮次:   1000, 训练准确率: 91.0000%
# Adding run metadata for 1200
# 迭代轮次:   1200, 训练准确率: 92.0000%
# Adding run metadata for 1400
# 迭代轮次:   1400, 训练准确率: 94.0000%
# 迭代轮次:   1500, 验证准确率: 91.4062%
# Adding run metadata for 1600
# 迭代轮次:   1600, 训练准确率: 95.0000%
# Adding run metadata for 1800
# 迭代轮次:   1800, 训练准确率: 97.0000%
# 迭代轮次:   2000, 验证准确率: 92.9688%
# Adding run metadata for 2000
# 迭代轮次:   2000, 训练准确率: 92.0000%
# Done training!
